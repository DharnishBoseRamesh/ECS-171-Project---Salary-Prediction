# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/brdmacbook/Desktop/ECS 171/ECS-171-Project---Salary-Prediction/data/process/clean_ai_salary_2025_merged_final.csv')
df.head()
# Out:
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
# 1  AI00002            ML Engineer       61895             USD
# 2  AI00003          AI Specialist      152626             USD
# 3  AI00004           NLP Engineer       80215             USD
# 4  AI00005          AI Consultant       54624             EUR
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
# 2               MI              FL      Switzerland            L
# 3               SE              FL            India            M
# 4               EN              PT           France            S
#
#   employee_residence  remote_ratio  \
# 0              China            50
# 1            Ireland           100
# 2        South Korea             0
# 3              India            50
# ...

# %%
#remove salary_currency column from the csv file

df = df.drop('salary_currency', axis=1)

#this actually changes value in the csv file
df.to_csv('/Users/brdmacbook/Desktop/ECS 171/ECS-171-Project---Salary-Prediction/data/process/clean_ai_salary_2025_merged_final.csv', index=False)

# %%
#check if changes are reflected
df.head()
# Out:
#     job_id              job_title  salary_usd experience_level  \
# 0  AI00001  AI Research Scientist       90376               SE
# 1  AI00002            ML Engineer       61895               EN
# 2  AI00003          AI Specialist      152626               MI
# 3  AI00004           NLP Engineer       80215               SE
# 4  AI00005          AI Consultant       54624               EN
#
#   employment_type company_location company_size employee_residence  \
# 0              CT            China            M              China
# 1              CT           Canada            M            Ireland
# 2              FL      Switzerland            L        South Korea
# 3              FL            India            M              India
# 4              PT           France            S          Singapore
#
#    remote_ratio                                  required_skills  \
# 0            50         Tableau, PyTorch, Kubernetes, Linux, NLP
# ...
